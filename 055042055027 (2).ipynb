# %% [markdown]
# # Data Exploration and Visualization using Python Group Project - 1

# %% [markdown]
# #### IMPORT/EXPORT ANALYSIS OF VARIOUS PRODUCTS

# %% [markdown]
# ##### Submitted to Prof. Amarnath Mitra by Shagun Seth (055042) and Rushil Kohli (055027)

# %% [markdown]
# ## Importing Relevant Python Libraries

# %%
import pandas as pd 
import os

# %% [markdown]
# ## Loading the Project's Data

# %%
file_path = r'/Users/shagunseth/Desktop/ImportsExportsDataset.csv' #Load the Test Data.
project=pd.read_csv(file_path)
my_project= pd.DataFrame(project);
my_project
# Out:
#                              Transaction_ID           Country    Product  \
# 0      e3e70682-c209-4cac-a29f-6fbed82c07cd          Colombia   describe
# 1      f728b4fa-4248-4e3a-8a5d-2f346baa9455             Chile  president
# 2      eb1167b3-67a9-4378-bc65-c1e582e2e662            Turkey        far
# 3      f7c1bd87-4da5-4709-9471-3d60c8a70639  Christmas Island     agency
# 4      e443df78-9558-467f-9ba9-1faf7a024204           Finland     policy
# ...                                     ...               ...        ...
# 14995  48df15a8-0823-4964-8c16-eddf2756f382  Marshall Islands        not
# 14996  31106617-94a6-4646-a001-5e7bd45abc26           Bermuda        air
# 14997  ee485839-fbde-4ced-af18-d98f5e863081          Tanzania       show
# 14998  5acd54aa-ec8c-4055-be8b-a447861a471c            Tuvalu         TV
# 14999  5cc039d0-a052-41fd-bfbb-c9f60c4565ac   North Macedonia       year
#
#       Import_Export  Quantity    Value        Date     Category  \
# ...

# %% [markdown]
# ## Data Source & Type

# %%
data_source = "Detailed Imports and Exports Dataset with Comprehensive Transaction Information: https://www.kaggle.com/datasets/chakilamvishwas/imports-exports-15000"
dataset_source = "https://www.kaggle.com/datasets/chakilamvishwas/imports-exports-15000"

print(f"Dataset Source: {dataset_source}")
# Out:
# Dataset Source: https://www.kaggle.com/datasets/chakilamvishwas/imports-exports-15000

# %%
my_project.shape
# Out:
# (15000, 16)

# %% [markdown]
# ## Creating a Unique Sample of 2001 Records using Student Roll Numbers as Random State.

# %%
my_sample=my_project.sample(n=2001, random_state=550425027) 
rows, columns = my_sample.shape
print(f"Number of rows: {rows}, Number of columns: {columns}") #f is being used so that it reads the value
# Out:
# Number of rows: 2001, Number of columns: 16

# %% [markdown]
# ## Description of the Data

# %% [markdown]
# ##### Data Type:

# %%
my_sample.dtypes
# Out:
# Transaction_ID      object
# Country             object
# Product             object
# Import_Export       object
# Quantity             int64
# Value              float64
# Date                object
# Category            object
# Port                object
# Customs_Code         int64
# Weight             float64
# Shipping_Method     object
# Supplier            object
# Customer            object
# Invoice_Number       int64
# Payment_Terms       object
# dtype: object

# %% [markdown]
# ##### Data Dimension:

# %%
my_sample.shape
# Out:
# (2001, 16)

# %% [markdown]
# ##### Data Variable Type:

# %%
my_sample.info
# Out:
# <bound method DataFrame.info of                              Transaction_ID         Country     Product  \
# 6674   75f81fc2-be1f-4c71-9a0b-9e2750ebf999        Mongolia        whom
# 14424  62146171-fe8d-45ca-b92c-96ff3cb4d677         Bolivia      choice
# 8009   9cb13287-1dad-4475-a858-35a5ae16eb0e       Singapore         few
# 2221   a2776fdf-f94c-40da-956d-3de3241fec26           Niger        hear
# 14140  d6754b23-d16b-4d95-bedd-f60519f16fe5          Kuwait    industry
# ...                                     ...             ...         ...
# 11713  2074d009-64fe-4cbd-b482-f0caf03c777c        Slovenia         may
# 860    ef82c4d6-438d-48b1-9719-64f8d2fb05ca  Western Sahara        song
# 863    86fe0ded-fe38-484b-b489-362c10345193       Greenland  successful
# 14604  2944e703-ea9b-43a0-becc-9e9bb6808d40        Honduras     million
# 5584   2d70b34e-e0d0-489b-bab1-a5e3dcfe2264         Morocco      simple
#
#       Import_Export  Quantity    Value        Date     Category  \
# ...

# %% [markdown]
# ##### Sample Information:

# %%
#Display the First 03 Records of the Sample Data.
my_sample.head(3)
# Out:
#                              Transaction_ID    Country Product Import_Export  \
# 6674   75f81fc2-be1f-4c71-9a0b-9e2750ebf999   Mongolia    whom        Export
# 14424  62146171-fe8d-45ca-b92c-96ff3cb4d677    Bolivia  choice        Import
# 8009   9cb13287-1dad-4475-a858-35a5ae16eb0e  Singapore     few        Export
#
#        Quantity    Value        Date     Category           Port  \
# 6674       9982  6437.03  18-06-2022    Furniture   Simpsonhaven
# 14424      1704  7264.42  09-10-2021    Machinery  New Catherine
# 8009       2429  3350.05  05-08-2021  Electronics  North Desiree
#
#        Customs_Code   Weight Shipping_Method                      Supplier  \
# 6674         745860  4610.53            Land  Hernandez, Johnson and Nixon
# 14424        890934  3445.99             Sea              Lambert-Campbell
# 8009         735541  3796.34            Land              Anderson-Sanders
#
#               Customer  Invoice_Number     Payment_Terms
# ...

# %%
#Obtain the column names of the pandas DataFrame
my_sample.columns.tolist()
# Out:
# ['Transaction_ID',
#  'Country',
#  'Product',
#  'Import_Export',
#  'Quantity',
#  'Value',
#  'Date',
#  'Category',
#  'Port',
#  'Customs_Code',
#  'Weight',
#  'Shipping_Method',
#  'Supplier',
#  'Customer',
#  'Invoice_Number',
#  'Payment_Terms']

# %% [markdown]
# ##### Data Variable Category:

# %%
#Identify & Display the List of the following Variables:
# 1. Index Variables[Transaction_ID]
# 2. Categorical Variables - Nominal Type [Country, Product, Import_Export, Category, Port, Customs_Code, Shipping_Method, Supplier, Customer, Invoice_Number]
# 3. Categorical Variables - Ordinal Type. [Payment_Terms]
# 4. Non-Categorical Variables [Quantity, Value, Date, Weight]

# %% [markdown]
# #### Subseting Categorical & Non Categorical Variables and Finding Descriptive Statistics of both

# %%
#Subset and Display the Non-Categorical Variables.
non_categorical = my_sample[['Quantity', 'Value', 'Date', 'Weight']]
non_categorical
# Out:
#        Quantity    Value        Date   Weight
# 6674       9982  6437.03  18-06-2022  4610.53
# 14424      1704  7264.42  09-10-2021  3445.99
# 8009       2429  3350.05  05-08-2021  3796.34
# 2221       6900  8881.52  07-11-2020  2006.02
# 14140      7282  1203.76  07-05-2021  2905.18
# ...         ...      ...         ...      ...
# 11713      5581  8987.34  13-03-2021  1442.10
# 860        7988  1087.26  17-05-2024  2736.57
# 863        6543  3786.10  08-09-2022  4737.49
# 14604      2597  6302.67  30-10-2022   652.40
# 5584       9775  1248.18  27-04-2022  2895.77
#
# [2001 rows x 4 columns]

# %%
#Display the Descriptive Statistics of the Non-Categorical Subset.
non_categorical.describe()
# Out:
#           Quantity        Value       Weight
# count  2001.000000  2001.000000  2001.000000
# mean   4926.629685  5078.998466  2498.333168
# std    2833.451226  2872.876768  1474.561393
# min      11.000000   106.830000     5.860000
# 25%    2466.000000  2548.780000  1211.490000
# 50%    4954.000000  5126.810000  2480.950000
# 75%    7320.000000  7504.480000  3787.400000
# max    9995.000000  9996.810000  4998.730000

# %%
#Subset and Display the Categorical Variables.
my_categorical = my_sample[['Country', 'Product', 'Import_Export', 'Category', 'Port', 'Customs_Code', 'Shipping_Method', 'Supplier', 'Customer', 'Invoice_Number']]
my_categorical
# Out:
#               Country     Product Import_Export     Category  \
# 6674         Mongolia        whom        Export    Furniture
# 14424         Bolivia      choice        Import    Machinery
# 8009        Singapore         few        Export  Electronics
# 2221            Niger        hear        Import     Clothing
# 14140          Kuwait    industry        Export    Machinery
# ...               ...         ...           ...          ...
# 11713        Slovenia         may        Export    Machinery
# 860    Western Sahara        song        Import         Toys
# 863         Greenland  successful        Export    Machinery
# 14604        Honduras     million        Export    Machinery
# 5584          Morocco      simple        Export  Electronics
#
#                     Port  Customs_Code Shipping_Method  \
# 6674        Simpsonhaven        745860            Land
# 14424      New Catherine        890934             Sea
# 8009       North Desiree        735541            Land
# ...

# %%
#Display the Descriptive Statistics of any 02 Categorical Variables.
my_categorical02 = my_sample[['Country','Product']]
my_categorical02.value_counts()
# Out:
# Country                       Product
# Svalbard & Jan Mayen Islands  edge       2
# Guyana                        unit       2
# Afghanistan                   case       1
# Oman                          medical    1
# Pakistan                      mind       1
#                                         ..
# Gabon                         wide       1
#                               throw      1
#                               sure       1
#                               so         1
# Zimbabwe                      top        1
# Name: count, Length: 1999, dtype: int64

# %% [markdown]
# ## Problem statements for drawing insights based on this data:

# %%
#Which is the Most and Least Preferred Country.
#What is the most frequently used shipping method?
#What is the largest category of imported & exported products?
#What is the total value of imported & exported products?
#What is the average weight of exported & imported goods?
#Which country has the highest quantity of imported & exported products?
#What are the top 5 suppliers based on the number of transactions?
#Which customer has made the most transactions?
#What is the total quantity of products imported by air?
#What is the total value of products exported by sea?
#What is the total number of transactions for 'Cash on Delivery' payment terms?
#What is the most common product in the dataset?
#What is the largest single transaction value in the dataset?
#What is the smallest single transaction value in the dataset?
#What is the average transaction value for products in the 'Furniture' category?
#What is the most common port for exporting goods?
#What is the most common port for importing goods?
#What percentage of total transactions are imports?
#What is the most common customs code in the dataset?
#What is the total quantity of products exported to Malaysia?
#Which payment term is most commonly used?
#What is the average value of transactions where payment terms are 'Prepaid'?
#What is the mean quantity of products per transaction?
#What is the median value of all transactions?
#What is the mode of the value of transactions?
#What is the average value of products imported by sea?
#What is the average value of products exported by land?
#What is the mean weight of products imported by each shipping method?
#What is the average transaction value for the top 3 customers?
#What is the average value of products exported by the top 3 countries (based on number of export transactions)?
#What is the average transaction quantity for the top 5 suppliers?

# %% [markdown]
# #### Insights:

# %%
#Display the Most and Least Preferred Country .
my_country = my_sample['Country'].value_counts()
my_country.head(1), my_country.tail(1)
# Out:
# (Country
#  Korea    21
#  Name: count, dtype: int64,
#  Country
#  Chad    2
#  Name: count, dtype: int64)

# %%
#What is the most frequently used shipping method?
most_used_shipping_method = my_sample['Shipping_Method'].value_counts().idxmax()
print("Most used shipping method:", most_used_shipping_method)
# Out:
# Most used shipping method: Air

# %%
#What is the largest category of imported products?
largest_import_category = my_sample[my_sample['Import_Export'] == 'Import']['Category'].value_counts().idxmax()
print("Largest imported category:", largest_import_category)
# Out:
# Largest imported category: Furniture

# %%
#What is the largest category of exported products?
largest_export_category = my_sample[my_sample['Import_Export'] == 'Export']['Category'].value_counts().idxmax()
print("Largest exported category:", largest_export_category)
# Out:
# Largest exported category: Electronics

# %%
#What is the total value of imported products?
total_import_value = my_sample[my_sample['Import_Export'] == 'Import']['Value'].sum()
print("Total value of imported products:", total_import_value)
# Out:
# Total value of imported products: 5209639.5

# %%
#What is the total value of exported products?
total_export_value = my_sample[my_sample['Import_Export'] == 'Export']['Value'].sum()
print("Total value of exported products:", total_export_value)
# Out:
# Total value of exported products: 4953436.43

# %%
#What is the average weight of imported goods?
average_import_weight = my_sample[my_sample['Import_Export'] == 'Import']['Weight'].mean()
print("Average weight of imported goods:", average_import_weight)
# Out:
# Average weight of imported goods: 2532.471724825523

# %%
#Which country has the highest quantity of imported products?
country_highest_import_quantity = my_sample[my_sample['Import_Export'] == 'Import'].groupby('Country')['Quantity'].sum().idxmax()
print("Country with highest quantity of imported products:", country_highest_import_quantity)
# Out:
# Country with highest quantity of imported products: Morocco

# %%
#Which country has the highest value of exported products?
country_highest_export_value = my_sample[my_sample['Import_Export'] == 'Export'].groupby('Country')['Value'].sum().idxmax()
print("Country with highest value of exported products:", country_highest_export_value)
# Out:
# Country with highest value of exported products: Korea

# %%
#What are the top 5 suppliers based on the number of transactions?
top_5_suppliers = my_sample['Supplier'].value_counts().head(5)
print("Top 5 suppliers:", top_5_suppliers)
# Out:
# Top 5 suppliers: Supplier
# Smith Group      3
# Roberts Group    3
# Lee LLC          3
# Brown PLC        3
# Davis PLC        3
# Name: count, dtype: int64

# %%
#Which customer has made the most transactions?
top_customer = my_sample['Customer'].value_counts().idxmax()
print("Customer with the most transactions:", top_customer)
# Out:
# Customer with the most transactions: Richard Allen

# %%
#What is the total quantity of products imported by air?
total_air_import_quantity = my_sample[(my_sample['Shipping_Method'] == 'Air') & (my_sample['Import_Export'] == 'Import')]['Quantity'].sum()
print("Total quantity of products imported by air:", total_air_import_quantity)
# Out:
# Total quantity of products imported by air: 1714941

# %%
#What is the total number of transactions for 'Cash on Delivery' payment terms?
cod_transactions = my_sample[my_sample['Payment_Terms'] == 'Cash on Delivery'].shape[0]
print("Total Cash on Delivery transactions:", cod_transactions)
# Out:
# Total Cash on Delivery transactions: 524

# %%
#What is the most common product in the dataset?
most_common_product = my_sample['Product'].value_counts().idxmax()
print("Most common product:", most_common_product)
# Out:
# Most common product: hotel

# %%
#What is the largest single transaction value in the dataset?
largest_transaction_value = my_sample['Value'].max()
print("Largest single transaction value:", largest_transaction_value)
# Out:
# Largest single transaction value: 9996.81

# %%
#What is the most common port for exporting goods?
most_common_export_port = my_sample[my_sample['Import_Export'] == 'Export']['Port'].value_counts().idxmax()
print("Most common export port:", most_common_export_port)
# Out:
# Most common export port: Michaelmouth

# %%
#What is the most common port for importing goods?
most_common_import_port = my_sample[my_sample['Import_Export'] == 'Import']['Port'].value_counts().idxmax()
print("Most common import port:", most_common_import_port)
# Out:
# Most common import port: Lake Michael

# %%
#What percentage of total transactions are imports?
import_percentage = (my_sample[my_sample['Import_Export'] == 'Import'].shape[0] / my_sample.shape[0]) * 100
print("Percentage of total transactions that are imports:", import_percentage)
# Out:
# Percentage of total transactions that are imports: 50.12493753123438

# %%
#What is the most common customs code in the dataset?
most_common_customs_code = my_sample['Customs_Code'].value_counts().idxmax()
print("Most common customs code:", most_common_customs_code)
# Out:
# Most common customs code: 239621

# %%
#Which payment term is most commonly used?
most_common_payment_term = my_sample['Payment_Terms'].value_counts().idxmax()
print("Most common payment term:", most_common_payment_term)
# Out:
# Most common payment term: Cash on Delivery

# %% [markdown]
# #### Inferential Statistics

# %%
#What is the average value of transactions where payment terms are 'Prepaid'?
average_prepaid_value = my_sample[my_sample['Payment_Terms'] == 'Prepaid']['Value'].mean()
print("Average transaction value for 'Prepaid' payment terms:", average_prepaid_value)
# Out:
# Average transaction value for 'Prepaid' payment terms: 5178.547001972387

# %%
#What is the mean quantity of products per transaction?
mean_quantity = my_sample['Quantity'].mean()
print("Mean quantity of products per transaction:", mean_quantity)
# Out:
# Mean quantity of products per transaction: 4926.629685157422

# %%
#What is the median value of all transactions?
median_value = my_sample['Value'].median()
print("Median value of all transactions:", median_value)
# Out:
# Median value of all transactions: 5126.81

# %%
#What is the mode of the value of transactions?
mode_value = my_sample['Value'].mode()[0]
print("Mode of transaction value:", mode_value)
# Out:
# Mode of transaction value: 241.83

# %%
#What is the average value of products imported by sea?
average_sea_import_value = my_sample[(my_sample['Shipping_Method'] == 'Sea') & (my_sample['Import_Export'] == 'Import')]['Value'].mean()
print("Average value of products imported by sea:", average_sea_import_value)
# Out:
# Average value of products imported by sea: 5159.917133956386

# %%
#What is the average value of products exported by land?
average_land_export_value = my_sample[(my_sample['Shipping_Method'] == 'Land') & (my_sample['Import_Export'] == 'Export')]['Value'].mean()
print("Average value of products exported by land:", average_land_export_value)
# Out:
# Average value of products exported by land: 5199.3975399361025

# %%
#What is the mean weight of products imported by each shipping method?
mean_import_weight_per_shipping_method = my_sample[my_sample['Import_Export'] == 'Import'].groupby('Shipping_Method')['Weight'].mean()
print("Mean weight of imported products per shipping method:\n", mean_import_weight_per_shipping_method)
# Out:
# Mean weight of imported products per shipping method:
#  Shipping_Method
# Air     2578.727378
# Land    2553.911582
# Sea     2460.094579
# Name: Weight, dtype: float64

# %%
#What is the average transaction value for the top 3 customers?
top_3_customers = my_sample['Customer'].value_counts().head(3).index
average_value_top_customers = my_sample[my_sample['Customer'].isin(top_3_customers)].groupby('Customer')['Value'].mean()
print("Average transaction value for top 3 customers:\n", average_value_top_customers)
# Out:
# Average transaction value for top 3 customers:
#  Customer
# Amanda Gomez      6351.075
# Jeffrey Miller    3113.660
# Richard Allen      660.140
# Name: Value, dtype: float64

# %%
#What is the average value of products exported by the top 3 countries (based on number of export transactions)?
top_3_export_countries = my_sample[my_sample['Import_Export'] == 'Export']['Country'].value_counts().head(3).index
average_value_top_export_countries = my_sample[(my_sample['Country'].isin(top_3_export_countries)) & (my_sample['Import_Export'] == 'Export')].groupby('Country')['Value'].mean()
print("Average value of exports for top 3 export countries:\n", average_value_top_export_countries)
# Out:
# Average value of exports for top 3 export countries:
#  Country
# Korea         5407.830667
# Latvia        3743.930000
# Tajikistan    3400.748182
# Name: Value, dtype: float64

# %%
#What is the average transaction quantity for the top 5 suppliers?
top_5_suppliers = my_sample['Supplier'].value_counts().head(5).index
average_quantity_top_suppliers = my_sample[my_sample['Supplier'].isin(top_5_suppliers)].groupby('Supplier')['Quantity'].mean()
print("Average transaction quantity for top 5 suppliers:\n", average_quantity_top_suppliers)
# Out:
# Average transaction quantity for top 5 suppliers:
#  Supplier
# Brown PLC        5879.333333
# Davis PLC        5595.000000
# Lee LLC          7246.666667
# Roberts Group    4707.666667
# Smith Group      5686.333333
# Name: Quantity, dtype: float64

# %% [markdown]
# #### Test of Proportion (Chi-square Test of Independence)

# %%
#Chi-square Test for Proportions of Import vs Export in Shipping Methods
import pandas as pd  # Import pandas
contingency_table = pd.crosstab(my_sample['Import_Export'], my_sample['Shipping_Method']) 

# Perform Chi-square test
from scipy.stats import chi2_contingency  # Import chi-square test function
chi2, p, dof, expected = chi2_contingency(contingency_table)

print(f"Chi-square statistic: {chi2}, P-value: {p}")
# Out:
# Chi-square statistic: 1.864655692662864, P-value: 0.3936363181526843

# %% [markdown]
# - Since the p-value is greater than 0.05, we fail to reject the null hypothesis.
# - This means that there is no statistically significant association between the two variables tested. In other words, the variables are likely independent of each other.

# %% [markdown]
# #### Test of Normality (Shapiro-Wilk Test)

# %%
# Shapiro-Wilk Test for Normality of Weight
from scipy.stats import shapiro
stat, p_value = shapiro(my_sample['Weight'])
print(f"Shapiro-Wilk Test Statistic: {stat}, P-value: {p_value}")
# Out:
# Shapiro-Wilk Test Statistic: 0.9492948958883207, P-value: 9.821732038170343e-26

# %% [markdown]
# - Since the p-value is significantly less than 0.05, we reject the null hypothesis.
# - This means that there is strong evidence to suggest that the data is not normally distributed.

# %% [markdown]
# #### Test of Variance (Levene’s / Bartlett’s Test)

# %%
# Levene’s Test for equal variances between Exports and Imports
from scipy.stats import levene
exports = my_sample[my_sample['Import_Export'] == 'Export']['Value']
imports = my_sample[my_sample['Import_Export'] == 'Import']['Value']
stat, p = levene(exports, imports)
print(f"Levene's Test Statistic: {stat}, P-value: {p}")
# Out:
# Levene's Test Statistic: 0.04200474868198222, P-value: 0.8376315865713608

# %% [markdown]
# - Since the p-value is greater than 0.05, we fail to reject the null hypothesis.
# - This means that there is no significant difference in the variances between the groups being compared. In other words, the groups likely have equal variances.

# %% [markdown]
# #### Test of Correlation (Pearson Correlation)

# %%
# Pearson Correlation between Value and Weight
correlation_value_weight = my_sample['Value'].corr(my_sample['Weight'])

print(f"Pearson Correlation between Value and Weight: {correlation_value_weight}")
# Out:
# Pearson Correlation between Value and Weight: -0.02655219473261525

# %% [markdown]
# - Since the correlation is very close to 0, there is almost no linear relationship between the transaction value and the weight of products in the dataset.
# - In practical terms, changes in product weight have little to no impact on the transaction value.

# %% [markdown]
# #### Test of Mean (t-test / ANOVA)

# %%
# t-test for Mean Difference in Value between Shipping Methods (e.g., Land vs Sea)
from scipy.stats import ttest_ind

land_value = my_sample[my_sample['Shipping_Method'] == 'Land']['Value']
sea_value = my_sample[my_sample['Shipping_Method'] == 'Sea']['Value']

t_stat, p_value = ttest_ind(land_value, sea_value)

print(f"T-statistic: {t_stat}, P-value: {p_value}")

# %% [markdown]
# #### Statistical Visualization

# %% [markdown]
# ###### Scatter Plot

# %%
# Create a scatter plot of Quantity vs Value
# Create a scatter plot of Value vs Weight, colored by Import/Export
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Value', y='Weight', hue='Import_Export', data=my_sample)
plt.title('Value vs Weight by Import/Export Status')
plt.xlabel('Value')
plt.ylabel('Weight')
plt.show()

# %% [markdown]
# ###### Line Chart

# %%
# Group by month and calculate average value
average_value_by_month = my_sample.groupby(my_sample['Date'].dt.to_period('M'))['Value'].mean()

# Create a line chart of average value over time (monthly)
plt.figure(figsize=(10, 6))
plt.plot(average_value_by_month.index.to_timestamp(), average_value_by_month.values)
plt.title('Average Transaction Value Over Time (Monthly)')
plt.xlabel('Month')
plt.ylabel('Average Value')
plt.show()

# %% [markdown]
# ###### Box-Whisker Plot

# %%
#Create a box plot for all non-categorical variables
plt.figure(figsize=(12, 8))
sns.boxplot(data=my_sample[['Quantity', 'Value', 'Weight']])
plt.title('Distribution of Non-Categorical Variables')
plt.show()

# %% [markdown]
# - Value: The "Value" variable has the widest distribution and the most outliers, indicating a large spread of transaction values with some exceptionally high values.
#
# - Quantity: The "Quantity" variable has a relatively narrow distribution with a few outliers. Most transactions involve smaller quantities, but there are some transactions with much larger quantities.
#
# - Weight: The "Weight" variable has a moderate spread with some outliers. The distribution is slightly skewed towards higher values, suggesting that there are more transactions with heavier items.

# %% [markdown]
# #### Statistical Visualization

# %% [markdown]
# ###### Bar

# %%
#Calculate average transaction value for each payment term
#Define custom colors for each bar
colors = ['blue', 'green', 'red', 'purple', 'orange']
average_value_by_payment_term = my_sample.groupby('Payment_Terms')['Value'].mean()

# Create the bar plot with custom colors
average_value_by_payment_term.plot(kind='bar', figsize=(10, 6), color=colors)
plt.title('Average Transaction Value by Payment Terms')
plt.xlabel('Payment Terms')
plt.ylabel('Average Transaction Value')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# The max number of transactions are through:Net30 & Prepaid mode, followed by Cash on Delivery & Net60

# %% [markdown]
# ###### Histogram

# %%
#We won't be able to make a histogram for this sample dataset as we have no numeric values present in the categorical variables.

# %% [markdown]
# ###### Pie

# %%
# Calculate the frequency of each shipping method
shipping_method_counts = my_sample['Shipping_Method'].value_counts()

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(shipping_method_counts, labels=shipping_method_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Distribution of Shipping Methods')
plt.show()

# %% [markdown]
# The most frequently used shipping method is Air followed by Sea & then Land.

# %% [markdown]
# ## Analysis/Observations

# %% [markdown]
# - Understanding Key Trading Patterns
#  By analyzing the most and least preferred countries, frequently used shipping methods, and top customers and suppliers, the objective is to identify high-value trade relationships and optimize supply chain strategies.
# - ⁠Optimize Logistics and Shipping
#  Questions related to shipping methods, average weight of goods, and specific shipping modes (air, sea, land) help in understanding logistical preferences, which can optimize cost, efficiency, and lead to better freight management.
# - ⁠Financial and Trade Balance Analysis
#  Determining the total value of imported and exported products and the balance between the two helps in monitoring the financial health of the company and understanding whether it is a net importer or exporter. This also aids in formulating pricing and profitability strategies.
# - Market Insights and Demand Analysis
#  Identifying the largest product categories for imports and exports, most common products, and specific country-wise trade volumes offers insights into market demand, allowing the business to focus on high-demand products and markets.
# - Payment and Transaction Trends
#  Analyzing payment terms, total transactions by payment methods, and the average transaction values provides insights into customer behavior and payment preferences. This allows the company to tailor payment options and policies to better suit their customers' needs.
# - Customer and Supplier Relationship Management
#  Understanding which customers make the most transactions and which suppliers have the highest number of transactions can guide relationship management strategies, ensuring that key partners and clients receive priority service and engagement.
# - Inventory and Capacity Management
#  Analyzing transaction quantities and product weights helps in planning inventory and logistics more effectively, ensuring that the company has sufficient stock and transport capacity to meet demand without over-investing in warehousing or shipping resources.
# - Cost and Performance Analysis
#  Questions related to transaction values, such as the largest and smallest transactions, average values for specific categories, and top customers, provide the opportunity to assess profitability and identify the most valuable customers and products, allowing for targeted marketing and sales strategies.
# - Risk and Compliance Monitoring
#  Understanding the most common customs codes, import/export preferences, and transaction patterns by payment terms aids in compliance with international trade regulations and helps manage risks associated with foreign trade.
# - Strategic Planning and Forecasting
#
# #Overall, these questions help the business forecast future trends, develop strategies for market expansion, optimize supply chain operations, and allocate resources more efficiently, ultimately leading to better business performance.

# %% [markdown]
# ## Managerial Insights

# %% [markdown]
# #Inferences Drawn from These Problem Statements:
# - 1. Identifying trends in shipping methods and payment terms can improve logistical planning and financial management.
# - 2. Understanding the average weight and value of imports/exports can assist in negotiating better freight and insurance deals.
# - 3. Recognizing the top contributing product categories and countries helps optimize inventory, focus on key markets, and make strategic trade decisions.
# - 4. Comparing the value of imported versus exported goods provides insights into trade imbalances or opportunities for growth in specific sectors.

# %% [markdown]
# ## Reccomendations

# %% [markdown]
# Based on the analysis and visualizations you've performed on this dataset, here are some potential recommendations:
#
# - Focus on high-value products and markets: Identify the products and countries that generate the highest transaction values and prioritize them in your business strategy. Consider expanding operations or marketing efforts in those areas.
# - Optimize shipping and logistics: Analyze the distribution of shipping methods and their associated costs. Explore opportunities to optimize shipping routes, negotiate better rates with carriers, or consider alternative transportation methods to reduce costs and improve delivery times.
# - Tailor payment options: Analyze the preferred payment terms of your customers and ensure you offer a variety of options to cater to their needs. Consider offering incentives for early payments or exploring more efficient payment processing methods.
# - Manage customer and supplier relationships: Identify your top customers and suppliers and develop strategies to nurture those relationships. Consider offering loyalty programs, personalized services, or exclusive deals to strengthen these partnerships.
# - Monitor and mitigate risks: Analyze customs codes and import/export regulations to ensure compliance and minimize potential risks associated with international trade. Stay informed about changes in regulations and implement appropriate measures to mitigate any potential disruptions.
# - Continuously analyze data: Regularly analyze your transaction data to identify emerging trends, potential issues, and opportunities for improvement. Use data-driven insights to inform your business decisions and optimize your operations.

# %% [markdown]
# ###
